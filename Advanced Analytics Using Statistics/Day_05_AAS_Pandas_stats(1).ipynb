# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/Advanced_Analytics_using_statistics/CDAC_DataBook.xlsx' ,sheet_name='ERPData')
df.head(5)
# Out:
#   MaterialID Location  Quantity
# 0    TMI-43T    MWH-4        34
# 1    AXCP-78    MWH-1        67
# 2    LXCV-21    MWH-2        27
# 3    AXCP-78    MWH-5        65
# 4    AXCP-78    MWH-4        36

# %%
x1 = np.random.randint(10,80,50)
x1

df['value'] = x1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.head()
# Out:
#   MaterialID Location  Quantity  value
# 0    TMI-43T    MWH-4        34     47
# 1    AXCP-78    MWH-1        67     68
# 2    LXCV-21    MWH-2        27     21
# 3    AXCP-78    MWH-5        65     32
# 4    AXCP-78    MWH-4        36     68

# %%
grp1 = df.groupby ('MaterialID')
print(grp1.groups         ,end='\n\n')
grp1.groups.keys()
# Out:
# {'AXCP-78': [1, 3, 4, 24, 25, 37, 38, 39, 46, 47, 48], 'DDBN-89': [22, 23, 26, 30, 40, 43, 45, 49], 'GCVB-79': [8, 15, 34, 35, 36], 'LXCV-21': [2, 27, 28, 29, 44], 'SDRT-67': [10, 11, 16, 17, 41, 42], 'TMI-43T': [0, 5, 6, 7, 9, 12, 13, 14, 18, 19, 20, 21, 31, 32, 33]}
# dict_keys(['AXCP-78', 'DDBN-89', 'GCVB-79', 'LXCV-21', 'SDRT-67', 'TMI-43T'])

# %%
df.iloc[[1, 3, 4, 24, 25, 37, 38, 39, 46, 47, 48]]
w1 = df.iloc[grp1.groups['AXCP-78']]
w1
# Out:
#    MaterialID Location  Quantity  value
# 1     AXCP-78    MWH-1        67     68
# 3     AXCP-78    MWH-5        65     32
# 4     AXCP-78    MWH-4        36     68
# 24    AXCP-78    MWH-1       152     64
# 25    AXCP-78    MWH-1       109     37
# 37    AXCP-78    MWH-5        65     43
# 38    AXCP-78    MWH-5        70     45
# 39    AXCP-78    MWH-1       145     13
# 46    AXCP-78    MWH-2        85     74
# 47    AXCP-78    MWH-3        29     14
# 48    AXCP-78    MWH-1        75     25

# %%
grp1.get_group('SDRT-67')
# Out:
#    MaterialID Location  Quantity  value
# 10    SDRT-67    MWH-1        34     68
# 11    SDRT-67    MWH-4        58     43
# 16    SDRT-67    MWH-5        12     41
# 17    SDRT-67    MWH-5       102     20
# 41    SDRT-67    MWH-1        57     49
# 42    SDRT-67    MWH-2        31     32

# %%
sns.barplot(w1['value'])
# Out:
# <Axes: ylabel='value'>

# %%
import seaborn as sns
sns.barplot(w1['Quantity'])
# Out:
# <Axes: ylabel='Quantity'>

# %%
grp1.Quantity.mean() ### Here we can directly give the agg function
grp1.Quantity.agg(np.mean)  ## here we have to pass the agg ftcn into agg
# Out:
# /tmp/ipykernel_12622/1029878589.py:2: FutureWarning: The provided callable <function mean at 0x78d2e4ff9940> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grp1.Quantity.agg(np.mean)  ## here we have to pass the agg ftcn into agg
# MaterialID
# AXCP-78    81.636364
# DDBN-89    47.875000
# GCVB-79    36.400000
# LXCV-21    48.600000
# SDRT-67    49.000000
# TMI-43T    59.000000
# Name: Quantity, dtype: float64

# %%
grp1.Quantity.mean()
grp1.Quantity.sum()
grp1.Quantity.size()
grp1.Quantity.agg([np.mean,np.sum,np.size])
# Out:
# /tmp/ipykernel_12622/171127097.py:4: FutureWarning: The provided callable <function mean at 0x78d2e4ff9940> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grp1.Quantity.agg([np.mean,np.sum,np.size])
# /tmp/ipykernel_12622/171127097.py:4: FutureWarning: The provided callable <function sum at 0x78d2e4ff8860> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grp1.Quantity.agg([np.mean,np.sum,np.size])
#                  mean  sum  size
# MaterialID
# AXCP-78     81.636364  898    11
# DDBN-89     47.875000  383     8
# GCVB-79     36.400000  182     5
# LXCV-21     48.600000  243     5
# SDRT-67     49.000000  294     6
# TMI-43T     59.000000  885    15

# %%
s1 = grp1.Quantity.size()  ## pandas.core.series.Series if there is a single column it is a series
type(s1)

s2 = grp1.Quantity.agg([np.mean,np.sum,np.size]) ## pandas.core.frame.DataFrame if there is a single column it is a DataFrame
type(s2)
# Out:
# /tmp/ipykernel_12622/4168461758.py:4: FutureWarning: The provided callable <function mean at 0x78d2e4ff9940> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   s2 = grp1.Quantity.agg([np.mean,np.sum,np.size]) ## pandas.core.frame.DataFrame if there is a single column it is a DataFrame
# /tmp/ipykernel_12622/4168461758.py:4: FutureWarning: The provided callable <function sum at 0x78d2e4ff8860> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   s2 = grp1.Quantity.agg([np.mean,np.sum,np.size]) ## pandas.core.frame.DataFrame if there is a single column it is a DataFrame
# pandas.core.frame.DataFrame

# %%
s1 = grp1.Quantity.agg(np.size)  ### now it is series
s1

d1 = pd.DataFrame(s1)  ## pandas.core.frame.DataFrame
d1
type(d1)
# Out:
# pandas.core.frame.DataFrame

# %%
d1.loc['SDRT-67']
# Out:
# Quantity    6
# Name: SDRT-67, dtype: int64

# %%
np.where(d1.index == 'SDRT-67')
d1

d1.loc['SDRT-67']
# Out:
# Quantity    6
# Name: SDRT-67, dtype: int64

# %%
np.where(d1.index == 'SDRT-67')
# Out:
# (array([4]),)

# %%
d1.iloc[np.where(d1.index == 'SDRT-67')]
# Out:
#             Quantity
# MaterialID
# SDRT-67            6

# %%
d2 = grp1.Quantity.agg([np.size,np.sum,np.size])
d2

d2.loc['SDRT-67' , 'sum']

# np.where(grp1.index == 'GCVB-79' )

d2.iloc[4,1]

d23 = np.where(d1.index == 'GCVB-79' )

d23 = d1.iloc[d23[0]]

type(d23)

d23
# Out:
# /tmp/ipykernel_12622/1378939958.py:1: FutureWarning: The provided callable <function sum at 0x78d2e4ff8860> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   d2 = grp1.Quantity.agg([np.size,np.sum,np.size])
#             Quantity
# MaterialID
# GCVB-79            5

# %% [markdown]
# ---
# #
#
#
#
#
#
#
# #
# ---

# %%
df = pd.read_excel('/content/drive/MyDrive/Advanced_Analytics_using_statistics/CDAC_DataBook.xlsx' , sheet_name = 'Health')
# df

# d = df.groupby(['Country','Disease'])
# d.groups

# %%
# | Part                             | Meaning                                                                |
# | -------------------------------- | ---------------------------------------------------------------------- |
# | `id_vars=['Country', 'Disease']` | These columns remain unchanged                                         |
# | `var_name='Year'`                | The melted column names become values under a new column called `Year` |
# | `value_name='Cases'`             | The data values go into a new column called `Cases`                    |


# the columns does not want to          the column names which i want to       the values of that columns that become
# change came in id_vars                 as value came in var_name             values that came in the value_name
#                   \--------------                        |                     ---------------/
#                                  V                       V                     V
df1 = df.melt(id_vars = ['Country' , 'Disease'] , var_name = 'Year' , value_name = 'Cases')
df1
# Out:
#    Country       Disease  Year  Cases
# 0    India        Cancer  2019     12
# 1       UK        Cancer  2019     95
# 2       US        Cancer  2019     98
# 3    Japan        Cancer  2019     89
# 4    India         Covid  2019     38
# 5       UK         Covid  2019     69
# 6       US         Covid  2019     87
# 7    Japan         Covid  2019     14
# 8    India  Heart Attack  2019     84
# 9       UK  Heart Attack  2019     44
# 10      US  Heart Attack  2019     34
# 11   Japan  Heart Attack  2019     11
# 12   India        Cancer  2020     94
# 13      UK        Cancer  2020     19
# 14      US        Cancer  2020     19
# 15   Japan        Cancer  2020     52
# 16   India         Covid  2020     19
# 17      UK         Covid  2020     73
# 18      US         Covid  2020     97
# 19   Japan         Covid  2020     12
# 20   India  Heart Attack  2020     10
# 21      UK  Heart Attack  2020     17
# 22      US  Heart Attack  2020     40
# 23   Japan  Heart Attack  2020     43
# 24   India        Cancer  2021     35
# 25      UK        Cancer  2021     84
# 26      US        Cancer  2021     53
# 27   Japan        Cancer  2021     14
# 28   India         Covid  2021     62
# 29      UK         Covid  2021     35
# 30      US         Covid  2021     35
# 31   Japan         Covid  2021     90
# 32   India  Heart Attack  2021     98
# 33      UK  Heart Attack  2021     24
# 34      US  Heart Attack  2021     54
# 35   Japan  Heart Attack  2021     75

# %%
print(df.shape)
df1.shape
# Out:
# (12, 5)
# (36, 4)

# %%
df2 = df1.pivot_table(values = 'Cases' , index = ['Country' ,'Year'] , columns = 'Disease')
df2
# Out:
# Disease       Cancer  Covid  Heart Attack
# Country Year
# India   2019    12.0   38.0          84.0
#         2020    94.0   19.0          10.0
#         2021    35.0   62.0          98.0
# Japan   2019    89.0   14.0          11.0
#         2020    52.0   12.0          43.0
#         2021    14.0   90.0          75.0
# UK      2019    95.0   69.0          44.0
#         2020    19.0   73.0          17.0
#         2021    84.0   35.0          24.0
# US      2019    98.0   87.0          34.0
#         2020    19.0   97.0          40.0
#         2021    53.0   35.0          54.0

# %%
df2.loc[ [['India',2019] , ['US',2019]] ]
df2.loc[ [['India', 2019]] ]
# Out:
# Disease       Cancer  Covid  Heart Attack
# Country Year
# India   2019    12.0   38.0          84.0

# %%
df2.index
# Out:
# MultiIndex([('India', 2019),
#             ('India', 2020),
#             ('India', 2021),
#             ('Japan', 2019),
#             ('Japan', 2020),
#             ('Japan', 2021),
#             (   'UK', 2019),
#             (   'UK', 2020),
#             (   'UK', 2021),
#             (   'US', 2019),
#             (   'US', 2020),
#             (   'US', 2021)],
#            names=['Country', 'Year'])

# %%
df211 = df1.pivot_table(values = 'Cases' , index = ['Year' , 'Country' ] , columns = 'Disease')
df211
# Out:
# Disease       Cancer  Covid  Heart Attack
# Year Country
# 2019 India      12.0   38.0          84.0
#      Japan      89.0   14.0          11.0
#      UK         95.0   69.0          44.0
#      US         98.0   87.0          34.0
# 2020 India      94.0   19.0          10.0
#      Japan      52.0   12.0          43.0
#      UK         19.0   73.0          17.0
#      US         19.0   97.0          40.0
# 2021 India      35.0   62.0          98.0
#      Japan      14.0   90.0          75.0
#      UK         84.0   35.0          24.0
#      US         53.0   35.0          54.0

# %%
df2.shape
# Out:
# (12, 3)

# %%
# .reset_index() it will remove labels from the DataFrame of the labels column
#  it will convert the labels into columns

df2 = df1.pivot_table(values = 'Cases' , index = ['Country' ,'Year'] , columns = 'Disease').reset_index()
print(df2)

print()

we = np.where(df2.Country == "India")
df2.iloc[we [0]]
# Out:
# Disease Country  Year  Cancer  Covid  Heart Attack
# 0         India  2019    12.0   38.0          84.0
# 1         India  2020    94.0   19.0          10.0
# 2         India  2021    35.0   62.0          98.0
# 3         Japan  2019    89.0   14.0          11.0
# 4         Japan  2020    52.0   12.0          43.0
# 5         Japan  2021    14.0   90.0          75.0
# 6            UK  2019    95.0   69.0          44.0
# 7            UK  2020    19.0   73.0          17.0
# 8            UK  2021    84.0   35.0          24.0
# 9            US  2019    98.0   87.0          34.0
# 10           US  2020    19.0   97.0          40.0
# 11           US  2021    53.0   35.0          54.0
# Disease Country  Year  Cancer  Covid  Heart Attack
# 0         India  2019    12.0   38.0          84.0
# 1         India  2020    94.0   19.0          10.0
# 2         India  2021    35.0   62.0          98.0

# %%
# rename_axis(columns = None) it will remove label name of the index column

df2 = df1.pivot_table(values = 'Cases' , index = ['Country' ,'Year'] , columns = 'Disease').reset_index().rename_axis(columns = None)
print(df2)
# Out:
#    Country  Year  Cancer  Covid  Heart Attack
# 0    India  2019    12.0   38.0          84.0
# 1    India  2020    94.0   19.0          10.0
# 2    India  2021    35.0   62.0          98.0
# 3    Japan  2019    89.0   14.0          11.0
# 4    Japan  2020    52.0   12.0          43.0
# 5    Japan  2021    14.0   90.0          75.0
# 6       UK  2019    95.0   69.0          44.0
# 7       UK  2020    19.0   73.0          17.0
# 8       UK  2021    84.0   35.0          24.0
# 9       US  2019    98.0   87.0          34.0
# 10      US  2020    19.0   97.0          40.0
# 11      US  2021    53.0   35.0          54.0

# %%
df = pd.read_excel('/content/drive/MyDrive/Advanced_Analytics_using_statistics/CDAC_DataBook.xlsx' , sheet_name = 'ERPData')
df.head()
# Out:
#   MaterialID Location  Quantity
# 0    TMI-43T    MWH-4        34
# 1    AXCP-78    MWH-1        67
# 2    LXCV-21    MWH-2        27
# 3    AXCP-78    MWH-5        65
# 4    AXCP-78    MWH-4        36

# %%
df1 = df.pivot_table(values = 'Quantity' ,index =['MaterialID'] , columns = 'Location') #<---------------- there is a default agg function is mean
df1 = df.pivot_table(values = 'Quantity' ,index =['MaterialID'] , columns = 'Location' , aggfunc = 'mean') # <=-------------you can change the agg function to sum ,size

df1 = df.pivot_table(values = 'Quantity' ,index =['MaterialID'] , columns = 'Location' , aggfunc = 'size')

print(df1.shape)
print("======================================================")
print(df1.reset_index())
# Out:
# (6, 5)
# ======================================================
# Location MaterialID  MWH-1  MWH-2  MWH-3  MWH-4  MWH-5
# 0           AXCP-78    5.0    1.0    1.0    1.0    3.0
# 1           DDBN-89    3.0    1.0    1.0    2.0    1.0
# 2           GCVB-79    NaN    4.0    NaN    NaN    1.0
# 3           LXCV-21    NaN    1.0    1.0    NaN    3.0
# 4           SDRT-67    2.0    1.0    NaN    1.0    2.0
# 5           TMI-43T    1.0    1.0    1.0   11.0    1.0

# %% [markdown]
# # *Data Summarization*

# %%
df.head()
# Out:
#   MaterialID Location  Quantity  value
# 0    TMI-43T    MWH-4        34     28
# 1    AXCP-78    MWH-1        67     56
# 2    LXCV-21    MWH-2        27     12
# 3    AXCP-78    MWH-5        65     42
# 4    AXCP-78    MWH-4        36     67

# %%
x1 = df.MaterialID
np.unique(x1)
# Out:
# array(['AXCP-78', 'DDBN-89', 'GCVB-79', 'LXCV-21', 'SDRT-67', 'TMI-43T'],
#       dtype=object)

# %%
len(np.unique(x1))
# Out:
# 6

# %%
np.unique(x1, return_counts=True)
# Out:
# (array(['AXCP-78', 'DDBN-89', 'GCVB-79', 'LXCV-21', 'SDRT-67', 'TMI-43T'],
#        dtype=object),
#  array([11,  8,  5,  5,  6, 15]))

# %%
x1.value_counts()
# Out:
# MaterialID
# TMI-43T    15
# AXCP-78    11
# DDBN-89     8
# SDRT-67     6
# GCVB-79     5
# LXCV-21     5
# Name: count, dtype: int64

# %%
x1.value_counts().reset_index()
# Out:
#   MaterialID  count
# 0    TMI-43T     15
# 1    AXCP-78     11
# 2    DDBN-89      8
# 3    SDRT-67      6
# 4    GCVB-79      5
# 5    LXCV-21      5

# %%
df1 = x1.value_counts().reset_index()

# %%
df1
# Out:
#   MaterialID  count
# 0    TMI-43T     15
# 1    AXCP-78     11
# 2    DDBN-89      8
# 3    SDRT-67      6
# 4    GCVB-79      5
# 5    LXCV-21      5

# %% [markdown]
# Find the proportion of given material ID

# %%
df1['prop'] = df1['count']/sum(df1['count'])

# %%
df1
# Out:
#   MaterialID  count  prop  percentage
# 0    TMI-43T     15  0.30        30.0
# 1    AXCP-78     11  0.22        22.0
# 2    DDBN-89      8  0.16        16.0
# 3    SDRT-67      6  0.12        12.0
# 4    GCVB-79      5  0.10        10.0
# 5    LXCV-21      5  0.10        10.0

# %%
df1['pct'] = df1['prop']*100

# %%
df1
# Out:
#   MaterialID  count  prop  percentage  CumPct   pct
# 0    TMI-43T     15  0.30        30.0    30.0  30.0
# 1    AXCP-78     11  0.22        22.0    52.0  22.0
# 2    DDBN-89      8  0.16        16.0    68.0  16.0
# 3    SDRT-67      6  0.12        12.0    80.0  12.0
# 4    GCVB-79      5  0.10        10.0    90.0  10.0
# 5    LXCV-21      5  0.10        10.0   100.0  10.0

# %%
x2 = np.array([4,7,5,2,3,8])

# %%
np.cumsum(x2)
# Out:
# array([ 4, 11, 16, 18, 21, 29])

# %%
df1 = df1.drop(columns=['percentage'])

# %%
df1
# Out:
#   MaterialID  count  prop  CumPct   pct
# 0    TMI-43T     15  0.30    30.0  30.0
# 1    AXCP-78     11  0.22    52.0  22.0
# 2    DDBN-89      8  0.16    68.0  16.0
# 3    SDRT-67      6  0.12    80.0  12.0
# 4    GCVB-79      5  0.10    90.0  10.0
# 5    LXCV-21      5  0.10   100.0  10.0

# %%
sns.barplot()

# %%
df2 = df2.drop(columns=['percentage'])

# %%
df2
# Out:
#    Country  Year  Cancer  Covid  Heart Attack
# 0    India  2019    12.0   38.0          84.0
# 1    India  2020    94.0   19.0          10.0
# 2    India  2021    35.0   62.0          98.0
# 3    Japan  2019    89.0   14.0          11.0
# 4    Japan  2020    52.0   12.0          43.0
# 5    Japan  2021    14.0   90.0          75.0
# 6       UK  2019    95.0   69.0          44.0
# 7       UK  2020    19.0   73.0          17.0
# 8       UK  2021    84.0   35.0          24.0
# 9       US  2019    98.0   87.0          34.0
# 10      US  2020    19.0   97.0          40.0
# 11      US  2021    53.0   35.0          54.0

# %%
x = np.array([3,4,5,6])
f = np.array([20,18,9,12])

# %%
mean = sum(x*f/sum(f))

# %%
mean
# Out:
# np.float64(4.220338983050848)

# %%
(800-8)/20+40
# Out:
# 79.6

# %%
pckg1 = [7,6,7,6,7,6,7,6,7,6,7,7,6,8,6,7,8,7,6,7,8,7,6,6,7,8]

# %%
pckg2 = [7,6,7,6,7,6,7,6,7,6,7,7,6,8,6,7,8,7,6,7,8,7,6,61,17,28,45]

# %%
np.mean(pckg1)
# Out:
# np.float64(6.769230769230769)

# %%
np.mean(pckg2)
# Out:
# np.float64(11.333333333333334)

# %%
np.median(pckg1)
# Out:
# np.float64(7.0)

# %%
np.median(pckg2)
# Out:
# np.float64(7.0)
